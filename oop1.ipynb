# %% [markdown]
# ## OOP
# ### to map with real world secenaries,we started using objects in code
# ### this is callled "object oriented programming "

# %% [markdown]
# ### Class and  Objects in python
# #### Class is a blueprint for creating objects
# ### creating class
# ### class Student:
# ### name="basit"
# ## creating object
# ### s1=student()
# ### print(s1.name)

# %%
'''class Student:
    name="basit"
s1=Student()## here we write class name
print(s1.name)## this called object
print(type(s1.name))
class Car:
    color="blue"
    brand="mercedes"
car1=Car()
print(car1.brand,car1.color)'''
# Out:
# 'class Student:\n    name="basit"\ns1=Student()## here we write class name\nprint(s1.name)## this called object\nprint(type(s1.name))\nclass Car:\n    color="blue"\n    brand="mercedes"\ncar1=Car()\nprint(car1.brand,car1.color)'

# %% [markdown]
# ## __init__function
# ### Constructor
# #### All classes have a function called init (),which is always executed when the object is being initiated

# %%
'''class Student:
      #default constructors
      #def __init__(self):
      #paramitarized constructors
    def __init__(self,fullname,marks): ## constructor
          self.name=fullname
          self.marks=marks
    def welcome(self):
         print("Abdul basit",self.marks)
    print("adding new student in a database")
s1=Student("brokhan",97)
#print(s1.name,s1.marks)
#s2=Student("basit",90)
#print(s2.name,s2.marks)
print(s1.welcome())'''
# Out:
# adding new student in a database
# Abdul basit 97
# None

# %%
## Q1
'''class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def get_avg(self):
     sum=0
     for val in self.marks:
        sum+=val
     print("hi",self.name,"your avg score is:",sum/3)
s1 =Student("tony stark",[90,80,100])   
s1.get_avg() 
s1.name="basit khan"   
s1.get_avg() '''
# Out:
# 'class Student:\n    def __init__(self,name,marks):\n        self.name=name\n        self.marks=marks\n    def get_avg(self):\n     sum=0\n     for val in self.marks:\n        sum+=val\n     print("hi",self.name,"your avg score is:",sum/3)\ns1 =Student("tony stark",[90,80,100])   \ns1.get_avg() \ns1.name="basit khan"   \ns1.get_avg() '

# %% [markdown]
# ## Static Methods
# ### methods that donot use the self parameter(work at class level)

# %%
class College:
    @staticmethod #decoder
    def dollege():
        print("Abc college")
s2=College()
s2.dollege()
# Out:
# Abc college

# %% [markdown]
# ## important
# ### Abstraction
# #### hiding the implementation details of a class and only showing the essential features to the user.
# ### Encapsulation
# #### wrapping data and functions into a single unit(object)

# %%
class Student:
  def __init__(self,fullname,marks): ## constructor
          self.name=fullname
          self.marks=marks
  def welcome(self):
         print("Abdul basit",self.marks)
print("adding new student in a database")
s1=Student("brokhan",97)
#print(s1.name,s1.marks)
#s2=Student("basit",90)
#print(s2.name,s2.marks)
print(s1.welcome())
# Out:
# adding new student in a database
# Abdul basit 97
# None

# %%
##Qp
class Account:
    def __init__(self,bal,acc):
        self.balance=bal
        self.accuont=acc

         
    def debit(self,ammount):
       self.balance -= ammount
       print("RS.",ammount,"was debited")
       print("total balance",self.get_balance())
        
    def credit(self,ammount):
       self.balance += ammount
       print("RS.",ammount,"was credit")
       print("total balance",self.get_balance())
        
    def get_balance(self):
       return self.balance  
acc1=Account(10000,1234)   
acc1.debit(1000)  
acc1.credit(500) 
acc1.credit(8000)
# Out:
# RS. 1000 was debited
# total balance 9000
# RS. 500 was credit
# total balance 9500
# RS. 8000 was credit
# total balance 17500

# %%
## del keyword (used to delete object properties or object itself)
## del s1.name (delete properties)
## del s1 (delet  object itself)
'''class Student:
    def __init__(self,name):
            self.username=name
        
s1=Student("basit")
print(s1.username) 
del s1.usernamename
print(s1.username)'''
# Out:
# 'class Student:\n    def __init__(self,name):\n            self.username=name\n\ns1=Student("basit")\nprint(s1.username) \ndel s1.usernamename\nprint(s1.username)'

# %% [markdown]
# ## Private(like)attribute and methods
# ### "conceptual implementation in python"
# ### private attr and metho are meant to be used only within the class and are not accessible from outside the class

# %%
class Student:
    def __init__(self,acc_pass,acc_no):
            self.__acc_password=acc_pass
            self.__acc_number=acc_no #here we take (__) to private

    def reset_pa(self):
        print(self.__acc_number)  
s1=Student(1234,"absc123")
#print(s1.__acc_number,s1.__acc_password)
print(s1.reset_pa())
# Out:
# absc123
# None

# %% [markdown]
# ## inheritan
# ### when one class(child/derived)derives the properties and methods of another class(parent/base)
# ## class Car: ...
# ## class ToyotaCar(car): .....

# %%
class Car:
    @staticmethod
    def start():
        print("car started")
    @staticmethod
    def stop():
        print("car stop")
class hondaCar(Car):
    def __init__(self,name):
 
      self.username=name  
car1=hondaCar("forniture")
car2=hondaCar("honda bro")
print(car2.username)
print(car2.stop())
# Out:
# honda bro
# car stop
# None

# %% [markdown]
# ## Types of inheritance
# ### >single inheritance
# ### >Multi-level inheritance
# ### >Multiple inheritance

# %%
## single inheritance
'''class Car:
    @staticmethod
    def start():
        print("car started")
    @staticmethod
    def stop():
        print("car stop")
class hondaCar(Car):
    def __init__(self,name):
 
      self.username=name  
car1=hondaCar("forniture")
car2=hondaCar("honda bro")
print(car2.username)
print(car2.stop())'''
## Multi-level inheritance
'''class Car:
    @staticmethod
    def start():
        print("car started")
    @staticmethod
    def stop():
        print("car stop")
class hondaCar(Car):
    def __init__(self,name):
 
      self.username=name  
class fortunie(hondaCar):
    def __init__(self,brand):
        self.Brand=brand
car1=fortunie("famous car in the world")
print(car1.Brand)'''
### Multiple inheritence
class A:
    varA="welcome to class A"
class B:
    varB="welcome to class B"
class C(A,B):
    varC="welcome to class C" 

c1=C()    
print(c1.varC)
print(c1.varA)
print(c1.varB)
# Out:
# welcome to class C
# welcome to class A
# welcome to class B

# %%
## Super method
## super()methods is used to access methods of the parents class
class Car:
    def __init__(self,type):
        self.type=type

    @staticmethod
    def start():
        print("car started")
    @staticmethod
    def stop():
        print("car stop")
class hondaCar(Car):
    def __init__(self,name,type):
        super().__init__(type)## this key that you access type from parent toward child
        self.name=name
        super().stop()
car1=hondaCar("pris","electric")
print(car1.type)
# Out:
# car stop
# electric

# %% [markdown]
# ## Class method
# ### a class method is bound to the class and recevies the class as an implicit first argument
# ### Note "static method cannot access or modify class state and generally for utility"
# #### class student:
# #### @classsmethod //decorator
# #### def collge(cls): pass

# %%
### review of it
'''class Person:

    name="abc"

    @classmethod
    def changeName(cls,name):
 
         cls.uname=name
s1=Person()
s1.changeName("brokhan") 
print(s1.uname) 
print(Person.name)'''
## property method()
class Student:
    def __init__(self,phy,ch,math):
        self.physic=phy
        self.chemistry=ch
        self.mathematics=math
    @property
    def percentage(self):
           return str((self.physic+self.chemistry+self.mathematics)/3)+"%"
stu1=Student(39,80,70)
print(stu1.percentage) 
stu1.physic=80
print(stu1.percentage)
# Out:
# 63.0%
# 76.66666666666667%

# %% [markdown]
# ### Polymorphism:operator Overloading(poly(many))
# #### when the same operator is allowed to have different meaning according to the context
# #### operators and Dunder functions
