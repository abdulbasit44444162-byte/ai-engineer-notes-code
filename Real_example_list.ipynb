# %% [markdown]
# ## Real-world Examples Using Lists in Python

# %% [markdown]
# ### lists are one of the most commonly used data structure in python,thanks to their versatility and ease of use. Here several practical examples that illustrate their use in real-world scenarios

# %% [markdown]
# ## Example 1.Manage A To DO List
#
# ### * Create a To Do list to keep track of Tasks

# %%
to_do_list=["buy objects","house wash","bills payment"]
### adding to task
to_do_list.append("basit")
print(to_do_list)
## removing a completed task
to_do_list.remove("buy objects")
print(to_do_list)
## checking if a task is in the list
if "bills payment" in to_do_list:
 print("donot forget this pay bills payment")
print("To do list remaing")   
for task in to_do_list:
    print(f"-{task}")
# Out:
# ['buy objects', 'house wash', 'bills payment', 'basit']
# ['house wash', 'bills payment', 'basit']
# donot forget this buy objects
# To do list remaing
# -house wash
# -bills payment
# -basit

# %% [markdown]
#  ## Example2:Organizing student Grades
#  ## >create a list to store and calculate average grades for students

# %%
## organizing student grades 
grades=[85,92,78,90,88]
# Adding a new grade
grades.append(95)

# calculating the average grade
average_grade=sum(grades)/len(grades)
print(f"Average Grade :{average_grade:.2f}")
# find highest and lowest grades
highest_grade=max(grades)
lowest_grade=min(grades)
print(f"highest Grade :{highest_grade}")
print(f"Lowest Grade :{lowest_grade}")
# Out:
# Average Grade :528.00
# highest Grade :95
# Lowest Grade :78

# %% [markdown]
# ## Managing An inventory
# ### > use list to manage inventory items in a store

# %%
# Manage inventory
inventory=["apple","bananas","oranges","grapes"]
# Adding a new item
inventory.append("strabery")
# deleting item 
inventory.remove("apple")
# checking if an item is in stock
item="oranges"
if item in inventory:
    print(f"{item} are in a stock")
else:
    print(f"{item}are out of stock") 

# print inventory
print("inventory list")
for item in inventory:
 print(f"{item}")
# Out:
# oranges are in a stock
# inventory list
# bananas
# oranges
# grapes
# strabery
