# %% [markdown]
# # Today we dicuss about condition

# %% [markdown]
# ## conditional statements
# ### if_elif_else
# ### if(condition)
# ###  statment1
# ### elif(condition)
# ###  statment2
# ### else:
# ### statement3

# %%
age=int(input())
if(age >=12):
    print("can vote $ apply for")


elif(age >10):

    print("you can vote but some days remaning for you")
else:
    print("bola kahan")
# Out:
# can vote $ apply for

# %%
# Program to calculate the sum of two user-provided numbers

# Take input from the user and convert to integers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# Calculate the sum
total_sum = num1 + num2

# Print the result
print("The sum is:", total_sum)
# Out:
# The sum is: 8

# %%
age=int(input())
if(age ==16):
    print("so hasan year old")# indentation mean proper space

else:
    print("bola kahan")
# Out:
# bola kahan
