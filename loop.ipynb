# %% [markdown]
# # LOOPS
# ### loops are used to repeat instructions

# %% [markdown]
# # WHILE LOOPS
# ## syantx
# ### while condition:
#    ## body of while loop
#    ## increment

# %%
i=1
while i<=10:
    print(i)
    i+=2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#num=[1,2,3,5,6,78,97,98,999]
num=["basit","khan","bro"]
index=0
'''while  index<len(num):
    print(index)
    index+=1'''
while index<len(num):   #if we do something like this that we arise one element so we (traverse)
    print(num[index])
    index+=1
# Out:
# basit
# khan
# bro

# %%
num=[1,2,3,5,6,78,97,98,999]
i=0
found=5
while i<len(num):
    if(num[i]==found):{
        print("i found",i)
    }
    i+=1
# Out:
# i found 3

# %% [markdown]
# ## Break and Continue

# %%
i=0    #break
while i<=5:
    if(i == 2):
     i +=1 
     continue
     
  
    print(i)
    
    i +=1
# Out:
# 0
# 1
# 3
# 4
# 5

# %%
i=1
while i<=10:
    if i==5:
      continue
      print(i)
      i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 i=1
# ----> 2 while i<=10:
#       3     if i==5:
#       4       continue
#
# KeyboardInterrupt:

# %% [markdown]
# ## forloop
# ## syantax
# ### for el in list,tuples or others
# ### body

# %%
list2=[1,2,3,4,5]
for el in list2:
    print(el)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## RANGE

# %%
'''seq= range(10)or
for el in range(10): range (stop)
 
 print(el)
for i in range(2,10): #range (start,stop)
    print(i)
for i in range(2,21,2):  # range(start,stop,step)
for i in range(100,0,-1):
    print(i)'''
#pass the pass statemnt is a null operation , it does nothing
for i in range(5):
    #empty
    pass
print("some useful work")
# Out:
# some useful work

# %%
## nested loops(a loop inside a loop)
for i in range(3):
    for j in range(2):
        print(f"i:{i}and j:{j}")
# Out:
# i:0and j:0
# i:0and j:1
# i:1and j:0
# i:1and j:1
# i:2and j:0
# i:2and j:1

# %%
i=1
while i<=10:
    if i==5:
      continue
      print(i)
      i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 i=1
# ----> 2 while i<=10:
#       3     if i==5:
#       4       continue
#
# KeyboardInterrupt:
