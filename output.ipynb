# %% [markdown]
# ## file I/O
# ### python can be used to perform operation on a file.(read & write data)
# ## types of all files
# ### text files:.txt,.docx,.log etc
# ### binary files:.mp4,.mov,.png,jpeg etc

# %%
f =open("docs.txt","r")
#data =f.read()
#data=f.readline() it means just read one line
#print(data)
#print(type(data))
f.close()
# Out:
# hi basit khan

# %%
# here we will writing in files
'''f =open("docs.txt","w")
data =f.write("jar khan saranga ee sha ya ee")
print(data)
f.close()
f =open("docs.txt","a")# here we append text
data =f.write("   \n what is your nick name"+" \n basit khan")
print(data)
f.close()
f =open("docs.txt","r+") here we do overwrite on next text
data =f.write("abc")
print(data)
f.close()
f =open("docs.txt","w+")#here we do to finished text then write text and (a+) mean to read and append notover werite
#data =f.write("abc")
data =f.read()
data=f.write("basit")
print(data)
f.close()'''
# Out:
# 5

# %% [markdown]
#  ### best syantax of file handling in python
#  #### with syantax
#  #### with open("demot.txt","a")as f:
#  ### data= f.read()
#  #### so here not use of "close()" becuse you use above "with"

# %%
with open("docs.txt","r") as f:

  data=f.read()
print(data)
# Out:
# abdul basit khan

# %%
import os
os.remove("file name here")

# %%
'''with open("practice.txt","r")as f:
    data=f.read()
newdata=data.replace("java","html") 

with open("practice.txt","w")as f:
    f.write(newdata)
    print("file succesfuly upload")'''
word="learning"
def basit():
     
 with open("practice.txt","r")as f:
    data=f.read()
    if(data.find(word) !=-1):

       print("found")
    else :
        print("not found")   
basit()
# Out:
# found
